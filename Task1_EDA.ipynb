# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

plt.style.use("ggplot")
# %matplotlib inline

# %% [markdown]
# # 🛒 SuperMarket Sales Analysis
#
# ### ApexPlanet Software Pvt. Ltd.
# ### Data Analytics Internship - Task 1
#
# **Name:** Laxmi Gupta
#
# **Tools Used:**
# - Python
# - Pandas
# - NumPy
# - Matplotlib
# - Seaborn

# %%
df = pd.read_csv("../Data/Raw_Data/SuperMarket Analysis.csv")

# %%
df.head()
# Out:
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428   Alex     Yangon        Member  Female
# 1  226-31-3081   Giza  Naypyitaw        Normal  Female
# 2  631-41-3108   Alex     Yangon        Normal  Female
# 3  123-19-1176   Alex     Yangon        Member  Female
# 4  373-73-7910   Alex     Yangon        Member  Female
#
#              Product line  Unit price  Quantity   Tax 5%     Sales       Date  \
# 0       Health and beauty       74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories       15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle       46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty       58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel       86.31         7  30.2085  634.3785   2/8/2019
#
#           Time      Payment    cogs  gross margin percentage  gross income  \
# 0   1:08:00 PM      Ewallet  522.83                 4.761905       26.1415
# ...

# %%
df.tail()
df.sample(5)
# Out:
#       Invoice ID Branch       City Customer type  Gender  \
# 59   120-06-4233   Giza  Naypyitaw        Member  Female
# 130  191-10-6171  Cairo   Mandalay        Normal  Female
# 984  189-40-5216   Giza  Naypyitaw        Normal    Male
# 172  733-33-4967   Giza  Naypyitaw        Normal    Male
# 822  784-21-9238   Giza  Naypyitaw        Member    Male
#
#                Product line  Unit price  Quantity   Tax 5%     Sales  \
# 59   Electronic accessories       30.61         6   9.1830  192.8430
# 130     Fashion accessories       39.62         7  13.8670  291.2070
# 984  Electronic accessories       96.37         7  33.7295  708.3195
# 172  Electronic accessories       20.85         8   8.3400  175.1400
# 822       Sports and travel       10.17         1   0.5085   10.6785
#
#           Date         Time Payment    cogs  gross margin percentage  \
# 59   3/12/2019   8:36:00 PM    Cash  183.66                 4.761905
# ...

# %% [markdown]
# We loaded the supermarket sales dataset successfully and verified the structure using head(), tail(), and sample().

# %%
df.shape
# Out:
# (1000, 17)

# %% [markdown]
# Total Records = 1000
# Total Columns = 17

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Sales', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='str')

# %% [markdown]
# Dataset has 17 features of costumers details, it show the product details and sales transaction.

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   str
#  1   Branch                   1000 non-null   str
#  2   City                     1000 non-null   str
#  3   Customer type            1000 non-null   str
#  4   Gender                   1000 non-null   str
#  5   Product line             1000 non-null   str
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   str
#  11  Time                     1000 non-null   str
#  12  Payment                  1000 non-null   str
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()

# %% [markdown]
# No missing values were found in the dataset.

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop_duplicates(inplace=True)

# %%
df.describe()
# Out:
#         Unit price     Quantity       Tax 5%        Sales        cogs  \
# count  1000.000000  1000.000000  1000.000000  1000.000000  1000.00000
# mean     55.672130     5.510000    15.379369   322.966749   307.58738
# std      26.494628     2.923431    11.708825   245.885335   234.17651
# min      10.080000     1.000000     0.508500    10.678500    10.17000
# 25%      32.875000     3.000000     5.924875   124.422375   118.49750
# 50%      55.230000     5.000000    12.088000   253.848000   241.76000
# 75%      77.935000     8.000000    22.445250   471.350250   448.90500
# max      99.960000    10.000000    49.650000  1042.650000   993.00000
#
#        gross margin percentage  gross income      Rating
# count              1000.000000   1000.000000  1000.00000
# mean                  4.761905     15.379369     6.97270
# std                   0.000000     11.708825     1.71858
# min                   4.761905      0.508500     4.00000
# ...

# %%
df.dtypes

# %%
df["Date"] = pd.to_datetime(df["Date"])
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   str
#  1   Branch                   1000 non-null   str
#  2   City                     1000 non-null   str
#  3   Customer type            1000 non-null   str
#  4   Gender                   1000 non-null   str
#  5   Product line             1000 non-null   str
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Sales                    1000 non-null   float64
#  10  Date                     1000 non-null   datetime64[us]
#  11  Time                     1000 non-null   str
#  12  Payment                  1000 non-null   str
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(" ", "_")

# %%
df.to_csv("../Data/Processed_Dataset/cleaned_supermarket.csv", index=False)

# %%
df.nunique()
# Out:
# invoice_id                 1000
# branch                        3
# city                          3
# customer_type                 2
# gender                        2
# product_line                  6
# unit_price                  943
# quantity                     10
# tax_5%                      990
# sales                       990
# date                         89
# time                        506
# payment                       3
# cogs                        990
# gross_margin_percentage       1
# gross_income                990
# rating                       61
# dtype: int64

# %% [markdown]
# The dataset contains 3 multiple branches,3 cities, 2 customer types, 6 product lines, and 3 payment methods, making it suitable for sales analysis.

# %%
df["city"].value_counts()
# Out:
# city
# Yangon       340
# Mandalay     332
# Naypyitaw    328
# Name: count, dtype: int64

# %% [markdown]
# Yangon city has the highest number of transaction

# %%
df["gender"].value_counts()
# Out:
# gender
# Female    571
# Male      429
# Name: count, dtype: int64

# %% [markdown]
# highest gender is female

# %%
df["customer_type"].value_counts()
# Out:
# customer_type
# Member    565
# Normal    435
# Name: count, dtype: int64

# %%
df["product_line"].value_counts()
# Out:
# product_line
# Fashion accessories       178
# Food and beverages        174
# Electronic accessories    170
# Sports and travel         166
# Home and lifestyle        160
# Health and beauty         152
# Name: count, dtype: int64

# %% [markdown]
# highest sales of product line is Fashion Accessories.

# %%
df["payment"].value_counts()
# Out:
# payment
# Ewallet        345
# Cash           344
# Credit card    311
# Name: count, dtype: int64

# %% [markdown]
# Ewallet payment method is used most

# %%
df.describe()
# Out:
#         unit_price     quantity       tax_5%        sales  \
# count  1000.000000  1000.000000  1000.000000  1000.000000
# mean     55.672130     5.510000    15.379369   322.966749
# min      10.080000     1.000000     0.508500    10.678500
# 25%      32.875000     3.000000     5.924875   124.422375
# 50%      55.230000     5.000000    12.088000   253.848000
# 75%      77.935000     8.000000    22.445250   471.350250
# max      99.960000    10.000000    49.650000  1042.650000
# std      26.494628     2.923431    11.708825   245.885335
#
#                              date        cogs  gross_margin_percentage  \
# count                        1000  1000.00000              1000.000000
# mean   2019-02-14 00:05:45.600000   307.58738                 4.761905
# min           2019-01-01 00:00:00    10.17000                 4.761905
# 25%           2019-01-24 00:00:00   118.49750                 4.761905
# 50%           2019-02-13 00:00:00   241.76000                 4.761905
# ...

# %%
plt.figure(figsize=(8,5))
sns.boxplot(x=df["sales"])
plt.title("Outliers in Sales")
plt.show()

# %%
Q1 = df["sales"].quantile(0.25)
Q3 = df["sales"].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

df = df[(df["sales"] >= lower) & (df["sales"] <= upper)]

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["sales"], bins=30, kde=True)
plt.title("Distribution of Sales")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# ### Observation
# - This chart shows the distribution of sales values.
# - Most transactions are concentrated in the middle range.
# - Very high sales transactions are less frequent.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="gender", data=df)
plt.title("Customer Gender Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - This chart shows the number of male and female customers.
# - Compare both categories and mention which one has more customers.

# %%
plt.figure(figsize=(6,4))
sns.countplot(x="customer_type", data=df)
plt.title("Customer Type Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - This chart compares Member and Normal customers.
# - Mention which customer type appears more frequently.

# %%
plt.figure(figsize=(10,5))
sns.countplot(y="product_line", data=df)
plt.title("Product Line Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - This chart shows the number of transactions in each product category.
# - Identify the most and least popular product line.

# %%
plt.figure(figsize=(7,4))
sns.countplot(x="payment", data=df)
plt.title("Payment Method Distribution")
plt.show()

# %% [markdown]
# ### Observation
# - This chart shows customers' preferred payment methods.
# - Mention which payment method is used most.

# %%
plt.figure(figsize=(6,4))
sns.barplot(x="branch", y="sales", data=df, estimator="sum")
plt.title("Total Sales by Branch")
plt.show()

# %% [markdown]
# ### Observation
# - This chart compares total sales across branches.
# - Mention which branch generated the highest revenue.

# %%
plt.figure(figsize=(8,5))
sns.barplot(x="city", y="sales", data=df, estimator="sum")
plt.title("Total Sales by City")
plt.show()

# %% [markdown]
# ### Observation
# - This chart compares total sales across different cities.
# - Identify the city with the highest sales.

# %%
plt.figure(figsize=(8,5))
sns.histplot(df["rating"], bins=20, kde=True)
plt.title("Customer Rating Distribution")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.scatterplot(x="quantity", y="sales", data=df)
plt.title("Quantity vs Sales")
plt.show()

# %% [markdown]
# ### Observation
# - Higher quantities generally result in higher sales.
# - This indicates a positive relationship between quantity and sales.

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %% [markdown]
# ### Observation
# - The heatmap shows relationships among numeric variables.
# - Identify the strongest positive and negative correlations.
